# %% [markdown]
# # Learning to make a market with mbt_gym and Stable Baselines 3

# %% [markdown]
# ### Import external modules

# %%
import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor

# %% [markdown]
# ### Add mbt-gym to path

# %%
import sys
sys.path.append("../src")

# %%
from agents.BaselineAgents import CarteaJaimungalMmAgent
from gym_local.helpers.generate_trajectory import generate_trajectory
from gym_local.StableBaselinesTradingEnvironment import StableBaselinesTradingEnvironment
from gym_local.TradingEnvironment import TradingEnvironment
from gym_local.wrappers import *
from rewards.RewardFunctions import PnL, CjMmCriterion
from stochastic_processes.midprice_models import BrownianMotionMidpriceModel
from stochastic_processes.arrival_models import PoissonArrivalModel
from stochastic_processes.fill_probability_models import ExponentialFillFunction
from gym_local.ModelDynamics import LimitOrderModelDynamics

# %% [markdown]
# ### Create market making environment

# %%
terminal_time = 1.0
arrival_rate = 10.0
n_steps = int(10 * terminal_time * arrival_rate)
phi = 0.5
alpha = 0.001

# %%
def get_cj_env(num_trajectories:int = 1):
    fill_exponent = 1
    sigma = 0.1
    initial_inventory = (-4,5)
    initial_price = 100
    step_size = 1/n_steps
    timestamps = np.linspace(0, terminal_time, n_steps + 1)
    midprice_model = BrownianMotionMidpriceModel(volatility=sigma, step_size=1/n_steps,
                                                 num_trajectories=num_trajectories)
    arrival_model = PoissonArrivalModel(intensity=np.array([arrival_rate, arrival_rate]), 
                                        step_size=1/n_steps, 
                                        num_trajectories=num_trajectories)
    fill_probability_model = ExponentialFillFunction(fill_exponent=fill_exponent, 
                                                     step_size=1/n_steps,
                                                     num_trajectories=num_trajectories)
    LOtrader = LimitOrderModelDynamics(midprice_model = midprice_model, arrival_model = arrival_model, 
                                fill_probability_model = fill_probability_model,
                                num_trajectories = num_trajectories)
    reward_function = CjMmCriterion(per_step_inventory_aversion = phi, terminal_inventory_aversion = alpha)
    env_params = dict(terminal_time=terminal_time, 
                      n_steps=n_steps,
                      initial_inventory = initial_inventory,
                      model_dynamics = LOtrader,
                      max_inventory=n_steps,
                      normalise_action_space = False,
                      normalise_observation_space = False,
                      reward_function = reward_function,
                      num_trajectories=num_trajectories)
    return TradingEnvironment(**env_params)

# %%
num_trajectories = 1000
env = ReduceStateSizeWrapper(get_cj_env(num_trajectories))
sb_env = StableBaselinesTradingEnvironment(trading_env=env)
# Out:
# /home/hamidou-diallo/Dev/Academic/deep_rl_market_making/.venv/lib/python3.12/site-packages/gymnasium/spaces/box.py:221: RuntimeWarning: overflow encountered in cast
#   elif low.dtype != self.dtype and np.any(low < dtype_min):
# /home/hamidou-diallo/Dev/Academic/deep_rl_market_making/.venv/lib/python3.12/site-packages/gymnasium/spaces/box.py:287: RuntimeWarning: overflow encountered in cast
#   elif high.dtype != self.dtype and np.any(dtype_max < high):

# %%
# Monitor sb_env
sb_env = VecMonitor(sb_env)
# Add directory for tensorboard logging and best model
tensorboard_logdir = "./tensorboard/PPO-learning-CJ/"
best_model_path = "./SB_models/PPO-best-CJ"

# %% [markdown]
# ### Define PPO policy

# %%
policy_kwargs = dict(net_arch=[dict(pi=[256, 256], vf=[256, 256])])
PPO_params = {"policy":'MlpPolicy', "env": sb_env, "verbose":1, 
              "policy_kwargs":policy_kwargs, 
              "tensorboard_log":tensorboard_logdir,
              "n_epochs":3,
              "batch_size": int(n_steps * num_trajectories / 10), 
              "n_steps": int(n_steps)}
callback_params = dict(eval_env=sb_env, n_eval_episodes = 2048, #200 before  (n_eval_episodes)
                       best_model_save_path = best_model_path, 
                       deterministic=True)

callback = EvalCallback(**callback_params)
model = PPO(**PPO_params, device="cpu")
# Out:
# /home/hamidou-diallo/Dev/Academic/deep_rl_market_making/.venv/lib/python3.12/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# Using cpu device

# %%
model.learn(total_timesteps = 10_000_000)  # Increase number of training timesteps according to computing resources
# Out:
# Logging to ./tensorboard/PPO-learning-CJ/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -4.22    |
# | time/              |          |
# |    fps             | 176597   |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 100000   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -4.17        |
# | time/                   |              |
# |    fps                  | 51555        |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 200000       |
# | train/                  |              |
# |    approx_kl            | 0.0026250433 |
# |    clip_fraction        | 0.00906      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.0103       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.908        |
# |    n_updates            | 3            |
# |    policy_gradient_loss | -0.000579    |
# |    std                  | 1            |
# |    value_loss           | 2            |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -3.61        |
# | time/                   |              |
# |    fps                  | 38815        |
# |    iterations           | 3            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 300000       |
# | train/                  |              |
# |    approx_kl            | 0.0021118298 |
# |    clip_fraction        | 0.00794      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.0469       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.847        |
# |    n_updates            | 6            |
# |    policy_gradient_loss | -0.000791    |
# |    std                  | 1            |
# |    value_loss           | 1.84         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -2.43       |
# | time/                   |             |
# |    fps                  | 34491       |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 400000      |
# | train/                  |             |
# |    approx_kl            | 0.003171655 |
# |    clip_fraction        | 0.0152      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.127       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.766       |
# |    n_updates            | 9           |
# |    policy_gradient_loss | -0.00113    |
# |    std                  | 1           |
# |    value_loss           | 1.76        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -2.63        |
# | time/                   |              |
# |    fps                  | 28228        |
# |    iterations           | 5            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 500000       |
# | train/                  |              |
# |    approx_kl            | 0.0029769242 |
# |    clip_fraction        | 0.0149       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.274        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.542        |
# |    n_updates            | 12           |
# |    policy_gradient_loss | -0.00109     |
# |    std                  | 1            |
# |    value_loss           | 1.34         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.6         |
# | time/                   |              |
# |    fps                  | 27976        |
# |    iterations           | 6            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 600000       |
# | train/                  |              |
# |    approx_kl            | 0.0040463093 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.425        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.649        |
# |    n_updates            | 15           |
# |    policy_gradient_loss | -0.00146     |
# |    std                  | 0.998        |
# |    value_loss           | 1.48         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.1         |
# | time/                   |              |
# |    fps                  | 28119        |
# |    iterations           | 7            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 700000       |
# | train/                  |              |
# |    approx_kl            | 0.0033788297 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.557        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.56         |
# |    n_updates            | 18           |
# |    policy_gradient_loss | -0.00111     |
# |    std                  | 0.996        |
# |    value_loss           | 1.21         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -0.316       |
# | time/                   |              |
# |    fps                  | 26577        |
# |    iterations           | 8            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 800000       |
# | train/                  |              |
# |    approx_kl            | 0.0037318463 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.615        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.566        |
# |    n_updates            | 21           |
# |    policy_gradient_loss | -0.0018      |
# |    std                  | 0.993        |
# |    value_loss           | 1.22         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -1.01       |
# | time/                   |             |
# |    fps                  | 26558       |
# |    iterations           | 9           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 900000      |
# | train/                  |             |
# |    approx_kl            | 0.003401262 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.662       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.55        |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.00161    |
# |    std                  | 0.991       |
# |    value_loss           | 1.11        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 0.834        |
# | time/                   |              |
# |    fps                  | 26482        |
# |    iterations           | 10           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 1000000      |
# | train/                  |              |
# |    approx_kl            | 0.0049072383 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.687        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.464        |
# |    n_updates            | 27           |
# |    policy_gradient_loss | -0.00196     |
# |    std                  | 0.984        |
# |    value_loss           | 0.957        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0.044       |
# | time/                   |             |
# |    fps                  | 26268       |
# |    iterations           | 11          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 1100000     |
# | train/                  |             |
# |    approx_kl            | 0.004952893 |
# |    clip_fraction        | 0.0337      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.43        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00219    |
# |    std                  | 0.976       |
# |    value_loss           | 0.894       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 0.573        |
# | time/                   |              |
# |    fps                  | 25697        |
# |    iterations           | 12           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 1200000      |
# | train/                  |              |
# |    approx_kl            | 0.0050269174 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.698        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.428        |
# |    n_updates            | 33           |
# |    policy_gradient_loss | -0.00212     |
# |    std                  | 0.969        |
# |    value_loss           | 0.921        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0.658       |
# | time/                   |             |
# |    fps                  | 25741       |
# |    iterations           | 13          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 1300000     |
# | train/                  |             |
# |    approx_kl            | 0.004574382 |
# |    clip_fraction        | 0.028       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.69        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.363       |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.00188    |
# |    std                  | 0.963       |
# |    value_loss           | 0.717       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 1.47        |
# | time/                   |             |
# |    fps                  | 24973       |
# |    iterations           | 14          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 1400000     |
# | train/                  |             |
# |    approx_kl            | 0.004305138 |
# |    clip_fraction        | 0.0262      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.667       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.333       |
# |    n_updates            | 39          |
# |    policy_gradient_loss | -0.00125    |
# |    std                  | 0.955       |
# |    value_loss           | 0.675       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 1.52        |
# | time/                   |             |
# |    fps                  | 25100       |
# |    iterations           | 15          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 1500000     |
# | train/                  |             |
# |    approx_kl            | 0.004274924 |
# |    clip_fraction        | 0.0277      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.639       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.287       |
# |    n_updates            | 42          |
# |    policy_gradient_loss | -0.00168    |
# |    std                  | 0.948       |
# |    value_loss           | 0.586       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 1.29        |
# | time/                   |             |
# |    fps                  | 25163       |
# |    iterations           | 16          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 1600000     |
# | train/                  |             |
# |    approx_kl            | 0.004168789 |
# |    clip_fraction        | 0.0334      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | 0.652       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.287       |
# |    n_updates            | 45          |
# |    policy_gradient_loss | -0.00132    |
# |    std                  | 0.938       |
# |    value_loss           | 0.598       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 2.27       |
# | time/                   |            |
# |    fps                  | 25237      |
# |    iterations           | 17         |
# |    time_elapsed         | 67         |
# |    total_timesteps      | 1700000    |
# | train/                  |            |
# |    approx_kl            | 0.00416992 |
# |    clip_fraction        | 0.0247     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.7       |
# |    explained_variance   | 0.643      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.264      |
# |    n_updates            | 48         |
# |    policy_gradient_loss | -0.00144   |
# |    std                  | 0.929      |
# |    value_loss           | 0.558      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 1.74        |
# | time/                   |             |
# |    fps                  | 25327       |
# |    iterations           | 18          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 1800000     |
# | train/                  |             |
# |    approx_kl            | 0.004472729 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.68       |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.27        |
# |    n_updates            | 51          |
# |    policy_gradient_loss | -0.00164    |
# |    std                  | 0.921       |
# |    value_loss           | 0.553       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 1.99        |
# | time/                   |             |
# |    fps                  | 25303       |
# |    iterations           | 19          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 1900000     |
# | train/                  |             |
# |    approx_kl            | 0.004326715 |
# |    clip_fraction        | 0.0251      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.66       |
# |    explained_variance   | 0.622       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.271       |
# |    n_updates            | 54          |
# |    policy_gradient_loss | -0.00157    |
# |    std                  | 0.912       |
# |    value_loss           | 0.54        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.02         |
# | time/                   |              |
# |    fps                  | 25254        |
# |    iterations           | 20           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0034683454 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.604        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.24         |
# |    n_updates            | 57           |
# |    policy_gradient_loss | -0.0013      |
# |    std                  | 0.903        |
# |    value_loss           | 0.5          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 2.62         |
# | time/                   |              |
# |    fps                  | 25310        |
# |    iterations           | 21           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 2100000      |
# | train/                  |              |
# |    approx_kl            | 0.0032945978 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.63        |
# |    explained_variance   | 0.584        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.25         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000874    |
# |    std                  | 0.896        |
# |    value_loss           | 0.494        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 2.48         |
# | time/                   |              |
# |    fps                  | 25326        |
# |    iterations           | 22           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 2200000      |
# | train/                  |              |
# |    approx_kl            | 0.0036791235 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.61        |
# |    explained_variance   | 0.585        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.249        |
# |    n_updates            | 63           |
# |    policy_gradient_loss | -0.00111     |
# |    std                  | 0.889        |
# |    value_loss           | 0.492        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 2.65         |
# | time/                   |              |
# |    fps                  | 25413        |
# |    iterations           | 23           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 2300000      |
# | train/                  |              |
# |    approx_kl            | 0.0034830365 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.59        |
# |    explained_variance   | 0.586        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.251        |
# |    n_updates            | 66           |
# |    policy_gradient_loss | -0.00114     |
# |    std                  | 0.88         |
# |    value_loss           | 0.501        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.29         |
# | time/                   |              |
# |    fps                  | 25484        |
# |    iterations           | 24           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 2400000      |
# | train/                  |              |
# |    approx_kl            | 0.0034161464 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.57        |
# |    explained_variance   | 0.574        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.242        |
# |    n_updates            | 69           |
# |    policy_gradient_loss | -0.000698    |
# |    std                  | 0.872        |
# |    value_loss           | 0.493        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 2.92         |
# | time/                   |              |
# |    fps                  | 25557        |
# |    iterations           | 25           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 2500000      |
# | train/                  |              |
# |    approx_kl            | 0.0036218825 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.56        |
# |    explained_variance   | 0.546        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.26         |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.00076     |
# |    std                  | 0.865        |
# |    value_loss           | 0.522        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 2.86        |
# | time/                   |             |
# |    fps                  | 25578       |
# |    iterations           | 26          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 2600000     |
# | train/                  |             |
# |    approx_kl            | 0.003044991 |
# |    clip_fraction        | 0.0124      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | 0.551       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.248       |
# |    n_updates            | 75          |
# |    policy_gradient_loss | -0.00044    |
# |    std                  | 0.859       |
# |    value_loss           | 0.515       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.11         |
# | time/                   |              |
# |    fps                  | 25739        |
# |    iterations           | 27           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 2700000      |
# | train/                  |              |
# |    approx_kl            | 0.0030614939 |
# |    clip_fraction        | 0.0144       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.53        |
# |    explained_variance   | 0.572        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.247        |
# |    n_updates            | 78           |
# |    policy_gradient_loss | -0.00032     |
# |    std                  | 0.852        |
# |    value_loss           | 0.507        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 2.6          |
# | time/                   |              |
# |    fps                  | 25892        |
# |    iterations           | 28           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 2800000      |
# | train/                  |              |
# |    approx_kl            | 0.0033189259 |
# |    clip_fraction        | 0.019        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.51        |
# |    explained_variance   | 0.566        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.246        |
# |    n_updates            | 81           |
# |    policy_gradient_loss | -0.000899    |
# |    std                  | 0.845        |
# |    value_loss           | 0.493        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.05         |
# | time/                   |              |
# |    fps                  | 25895        |
# |    iterations           | 29           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 2900000      |
# | train/                  |              |
# |    approx_kl            | 0.0028980155 |
# |    clip_fraction        | 0.00827      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.49        |
# |    explained_variance   | 0.564        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.266        |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.000398    |
# |    std                  | 0.838        |
# |    value_loss           | 0.522        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 2.83         |
# | time/                   |              |
# |    fps                  | 25703        |
# |    iterations           | 30           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 3000000      |
# | train/                  |              |
# |    approx_kl            | 0.0027254296 |
# |    clip_fraction        | 0.00706      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.48        |
# |    explained_variance   | 0.545        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.261        |
# |    n_updates            | 87           |
# |    policy_gradient_loss | -0.000344    |
# |    std                  | 0.833        |
# |    value_loss           | 0.521        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.39         |
# | time/                   |              |
# |    fps                  | 25660        |
# |    iterations           | 31           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 3100000      |
# | train/                  |              |
# |    approx_kl            | 0.0030017747 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 0.55         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.263        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000672    |
# |    std                  | 0.825        |
# |    value_loss           | 0.52         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 3.97        |
# | time/                   |             |
# |    fps                  | 25687       |
# |    iterations           | 32          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 3200000     |
# | train/                  |             |
# |    approx_kl            | 0.003137761 |
# |    clip_fraction        | 0.0108      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.44       |
# |    explained_variance   | 0.524       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.267       |
# |    n_updates            | 93          |
# |    policy_gradient_loss | -0.000502   |
# |    std                  | 0.819       |
# |    value_loss           | 0.533       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.61         |
# | time/                   |              |
# |    fps                  | 25733        |
# |    iterations           | 33           |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 3300000      |
# | train/                  |              |
# |    approx_kl            | 0.0013887485 |
# |    clip_fraction        | 0.00784      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.43        |
# |    explained_variance   | 0.533        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.267        |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.000392    |
# |    std                  | 0.813        |
# |    value_loss           | 0.529        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 2.89         |
# | time/                   |              |
# |    fps                  | 25804        |
# |    iterations           | 34           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 3400000      |
# | train/                  |              |
# |    approx_kl            | 0.0028370486 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.42        |
# |    explained_variance   | 0.538        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.256        |
# |    n_updates            | 99           |
# |    policy_gradient_loss | -0.000486    |
# |    std                  | 0.806        |
# |    value_loss           | 0.521        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.51         |
# | time/                   |              |
# |    fps                  | 25814        |
# |    iterations           | 35           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 3500000      |
# | train/                  |              |
# |    approx_kl            | 0.0021491728 |
# |    clip_fraction        | 0.00501      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.4         |
# |    explained_variance   | 0.532        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.262        |
# |    n_updates            | 102          |
# |    policy_gradient_loss | -0.000161    |
# |    std                  | 0.8          |
# |    value_loss           | 0.543        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.27         |
# | time/                   |              |
# |    fps                  | 25836        |
# |    iterations           | 36           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 3600000      |
# | train/                  |              |
# |    approx_kl            | 0.0027003882 |
# |    clip_fraction        | 0.00827      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.38        |
# |    explained_variance   | 0.554        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.284        |
# |    n_updates            | 105          |
# |    policy_gradient_loss | -0.000292    |
# |    std                  | 0.794        |
# |    value_loss           | 0.547        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 3.79        |
# | time/                   |             |
# |    fps                  | 25899       |
# |    iterations           | 37          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 3700000     |
# | train/                  |             |
# |    approx_kl            | 0.001722438 |
# |    clip_fraction        | 0.00779     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.37       |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.262       |
# |    n_updates            | 108         |
# |    policy_gradient_loss | -0.00016    |
# |    std                  | 0.787       |
# |    value_loss           | 0.541       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.41         |
# | time/                   |              |
# |    fps                  | 25936        |
# |    iterations           | 38           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 3800000      |
# | train/                  |              |
# |    approx_kl            | 0.0018487622 |
# |    clip_fraction        | 0.00308      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.35        |
# |    explained_variance   | 0.555        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.285        |
# |    n_updates            | 111          |
# |    policy_gradient_loss | -7.84e-05    |
# |    std                  | 0.783        |
# |    value_loss           | 0.559        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 4.09        |
# | time/                   |             |
# |    fps                  | 25990       |
# |    iterations           | 39          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 3900000     |
# | train/                  |             |
# |    approx_kl            | 0.002026552 |
# |    clip_fraction        | 0.00901     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.34       |
# |    explained_variance   | 0.557       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.266       |
# |    n_updates            | 114         |
# |    policy_gradient_loss | -0.000489   |
# |    std                  | 0.778       |
# |    value_loss           | 0.533       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.81         |
# | time/                   |              |
# |    fps                  | 26037        |
# |    iterations           | 40           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 4000000      |
# | train/                  |              |
# |    approx_kl            | 0.0019240745 |
# |    clip_fraction        | 0.00379      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.33        |
# |    explained_variance   | 0.541        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.286        |
# |    n_updates            | 117          |
# |    policy_gradient_loss | -0.000265    |
# |    std                  | 0.774        |
# |    value_loss           | 0.567        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.84         |
# | time/                   |              |
# |    fps                  | 26142        |
# |    iterations           | 41           |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 4100000      |
# | train/                  |              |
# |    approx_kl            | 0.0031508028 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.32        |
# |    explained_variance   | 0.545        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.276        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000613    |
# |    std                  | 0.769        |
# |    value_loss           | 0.552        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.23         |
# | time/                   |              |
# |    fps                  | 26233        |
# |    iterations           | 42           |
# |    time_elapsed         | 160          |
# |    total_timesteps      | 4200000      |
# | train/                  |              |
# |    approx_kl            | 0.0017023744 |
# |    clip_fraction        | 0.0057       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.31        |
# |    explained_variance   | 0.547        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.276        |
# |    n_updates            | 123          |
# |    policy_gradient_loss | -0.00014     |
# |    std                  | 0.764        |
# |    value_loss           | 0.569        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.31         |
# | time/                   |              |
# |    fps                  | 26298        |
# |    iterations           | 43           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 4300000      |
# | train/                  |              |
# |    approx_kl            | 0.0019045031 |
# |    clip_fraction        | 0.00938      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 0.533        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.29         |
# |    n_updates            | 126          |
# |    policy_gradient_loss | -0.000235    |
# |    std                  | 0.759        |
# |    value_loss           | 0.563        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.31         |
# | time/                   |              |
# |    fps                  | 26383        |
# |    iterations           | 44           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 4400000      |
# | train/                  |              |
# |    approx_kl            | 0.0021221826 |
# |    clip_fraction        | 0.00501      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.28        |
# |    explained_variance   | 0.534        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.302        |
# |    n_updates            | 129          |
# |    policy_gradient_loss | -0.000219    |
# |    std                  | 0.755        |
# |    value_loss           | 0.604        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.88         |
# | time/                   |              |
# |    fps                  | 26428        |
# |    iterations           | 45           |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 4500000      |
# | train/                  |              |
# |    approx_kl            | 0.0024997662 |
# |    clip_fraction        | 0.00621      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.27        |
# |    explained_variance   | 0.557        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.29         |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -0.000119    |
# |    std                  | 0.75         |
# |    value_loss           | 0.586        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.77         |
# | time/                   |              |
# |    fps                  | 26496        |
# |    iterations           | 46           |
# |    time_elapsed         | 173          |
# |    total_timesteps      | 4600000      |
# | train/                  |              |
# |    approx_kl            | 0.0014585392 |
# |    clip_fraction        | 0.00522      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.26        |
# |    explained_variance   | 0.565        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.275        |
# |    n_updates            | 135          |
# |    policy_gradient_loss | -0.00015     |
# |    std                  | 0.746        |
# |    value_loss           | 0.552        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.51         |
# | time/                   |              |
# |    fps                  | 26527        |
# |    iterations           | 47           |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 4700000      |
# | train/                  |              |
# |    approx_kl            | 0.0014160484 |
# |    clip_fraction        | 0.00486      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.25        |
# |    explained_variance   | 0.554        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.292        |
# |    n_updates            | 138          |
# |    policy_gradient_loss | 3.41e-05     |
# |    std                  | 0.741        |
# |    value_loss           | 0.565        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.11         |
# | time/                   |              |
# |    fps                  | 26521        |
# |    iterations           | 48           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 4800000      |
# | train/                  |              |
# |    approx_kl            | 0.0022673323 |
# |    clip_fraction        | 0.00923      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.23        |
# |    explained_variance   | 0.533        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.324        |
# |    n_updates            | 141          |
# |    policy_gradient_loss | -0.000121    |
# |    std                  | 0.737        |
# |    value_loss           | 0.614        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.8          |
# | time/                   |              |
# |    fps                  | 26424        |
# |    iterations           | 49           |
# |    time_elapsed         | 185          |
# |    total_timesteps      | 4900000      |
# | train/                  |              |
# |    approx_kl            | 0.0023959994 |
# |    clip_fraction        | 0.00492      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.22        |
# |    explained_variance   | 0.55         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.297        |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.000205    |
# |    std                  | 0.733        |
# |    value_loss           | 0.574        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 3.75        |
# | time/                   |             |
# |    fps                  | 26274       |
# |    iterations           | 50          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 5000000     |
# | train/                  |             |
# |    approx_kl            | 0.002277711 |
# |    clip_fraction        | 0.00542     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 0.536       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.296       |
# |    n_updates            | 147         |
# |    policy_gradient_loss | -0.000104   |
# |    std                  | 0.728       |
# |    value_loss           | 0.597       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.26         |
# | time/                   |              |
# |    fps                  | 26100        |
# |    iterations           | 51           |
# |    time_elapsed         | 195          |
# |    total_timesteps      | 5100000      |
# | train/                  |              |
# |    approx_kl            | 0.0018388141 |
# |    clip_fraction        | 0.00714      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.2         |
# |    explained_variance   | 0.533        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.293        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000165    |
# |    std                  | 0.724        |
# |    value_loss           | 0.599        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.62         |
# | time/                   |              |
# |    fps                  | 26032        |
# |    iterations           | 52           |
# |    time_elapsed         | 199          |
# |    total_timesteps      | 5200000      |
# | train/                  |              |
# |    approx_kl            | 0.0006541003 |
# |    clip_fraction        | 0.00135      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | 0.518        |
# ...
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.98         |
# | time/                   |              |
# |    fps                  | 25540        |
# |    iterations           | 84           |
# |    time_elapsed         | 328          |
# |    total_timesteps      | 8400000      |
# | train/                  |              |
# |    approx_kl            | 0.0028250297 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.84        |
# |    explained_variance   | 0.571        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.296        |
# |    n_updates            | 249          |
# |    policy_gradient_loss | -0.000195    |
# |    std                  | 0.605        |
# |    value_loss           | 0.604        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.03         |
# | time/                   |              |
# |    fps                  | 25507        |
# |    iterations           | 85           |
# |    time_elapsed         | 333          |
# |    total_timesteps      | 8500000      |
# | train/                  |              |
# |    approx_kl            | 0.0012435558 |
# |    clip_fraction        | 0.00557      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.83        |
# |    explained_variance   | 0.586        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.308        |
# |    n_updates            | 252          |
# |    policy_gradient_loss | 0.000176     |
# |    std                  | 0.602        |
# |    value_loss           | 0.611        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.55         |
# | time/                   |              |
# |    fps                  | 25497        |
# |    iterations           | 86           |
# |    time_elapsed         | 337          |
# |    total_timesteps      | 8600000      |
# | train/                  |              |
# |    approx_kl            | 0.0021087578 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.82        |
# |    explained_variance   | 0.58         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.302        |
# |    n_updates            | 255          |
# |    policy_gradient_loss | -0.000193    |
# |    std                  | 0.599        |
# |    value_loss           | 0.607        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.04         |
# | time/                   |              |
# |    fps                  | 25484        |
# |    iterations           | 87           |
# |    time_elapsed         | 341          |
# |    total_timesteps      | 8700000      |
# | train/                  |              |
# |    approx_kl            | 0.0014652412 |
# |    clip_fraction        | 0.00599      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.81        |
# |    explained_variance   | 0.564        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.306        |
# |    n_updates            | 258          |
# |    policy_gradient_loss | -0.000106    |
# |    std                  | 0.597        |
# |    value_loss           | 0.615        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.13         |
# | time/                   |              |
# |    fps                  | 25449        |
# |    iterations           | 88           |
# |    time_elapsed         | 345          |
# |    total_timesteps      | 8800000      |
# | train/                  |              |
# |    approx_kl            | 0.0019415449 |
# |    clip_fraction        | 0.00754      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.8         |
# |    explained_variance   | 0.58         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.296        |
# |    n_updates            | 261          |
# |    policy_gradient_loss | 0.000126     |
# |    std                  | 0.595        |
# |    value_loss           | 0.587        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.2          |
# | time/                   |              |
# |    fps                  | 25426        |
# |    iterations           | 89           |
# |    time_elapsed         | 350          |
# |    total_timesteps      | 8900000      |
# | train/                  |              |
# |    approx_kl            | 0.0021434112 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.8         |
# |    explained_variance   | 0.577        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.298        |
# |    n_updates            | 264          |
# |    policy_gradient_loss | 0.000142     |
# |    std                  | 0.592        |
# |    value_loss           | 0.598        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.27         |
# | time/                   |              |
# |    fps                  | 25402        |
# |    iterations           | 90           |
# |    time_elapsed         | 354          |
# |    total_timesteps      | 9000000      |
# | train/                  |              |
# |    approx_kl            | 0.0014991697 |
# |    clip_fraction        | 0.0113       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | 0.58         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.295        |
# |    n_updates            | 267          |
# |    policy_gradient_loss | -5.18e-05    |
# |    std                  | 0.589        |
# |    value_loss           | 0.593        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 4.31        |
# | time/                   |             |
# |    fps                  | 25397       |
# |    iterations           | 91          |
# |    time_elapsed         | 358         |
# |    total_timesteps      | 9100000     |
# | train/                  |             |
# |    approx_kl            | 0.002188578 |
# |    clip_fraction        | 0.0083      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.306       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.000254    |
# |    std                  | 0.587       |
# |    value_loss           | 0.604       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.9          |
# | time/                   |              |
# |    fps                  | 25366        |
# |    iterations           | 92           |
# |    time_elapsed         | 362          |
# |    total_timesteps      | 9200000      |
# | train/                  |              |
# |    approx_kl            | 0.0016769354 |
# |    clip_fraction        | 0.00435      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | 0.579        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.293        |
# |    n_updates            | 273          |
# |    policy_gradient_loss | -0.000118    |
# |    std                  | 0.583        |
# |    value_loss           | 0.585        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.88         |
# | time/                   |              |
# |    fps                  | 25360        |
# |    iterations           | 93           |
# |    time_elapsed         | 366          |
# |    total_timesteps      | 9300000      |
# | train/                  |              |
# |    approx_kl            | 0.0019269648 |
# |    clip_fraction        | 0.00523      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 0.59         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.282        |
# |    n_updates            | 276          |
# |    policy_gradient_loss | -7.39e-06    |
# |    std                  | 0.579        |
# |    value_loss           | 0.564        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.31         |
# | time/                   |              |
# |    fps                  | 25333        |
# |    iterations           | 94           |
# |    time_elapsed         | 371          |
# |    total_timesteps      | 9400000      |
# | train/                  |              |
# |    approx_kl            | 0.0026495855 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.588        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.288        |
# |    n_updates            | 279          |
# |    policy_gradient_loss | 5.11e-05     |
# |    std                  | 0.576        |
# |    value_loss           | 0.569        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.36         |
# | time/                   |              |
# |    fps                  | 25282        |
# |    iterations           | 95           |
# |    time_elapsed         | 375          |
# |    total_timesteps      | 9500000      |
# | train/                  |              |
# |    approx_kl            | 0.0032964095 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.73        |
# |    explained_variance   | 0.579        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.296        |
# |    n_updates            | 282          |
# |    policy_gradient_loss | -0.000327    |
# |    std                  | 0.573        |
# |    value_loss           | 0.574        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.11         |
# | time/                   |              |
# |    fps                  | 25276        |
# |    iterations           | 96           |
# |    time_elapsed         | 379          |
# |    total_timesteps      | 9600000      |
# | train/                  |              |
# |    approx_kl            | 0.0024376132 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.72        |
# |    explained_variance   | 0.588        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.282        |
# |    n_updates            | 285          |
# |    policy_gradient_loss | -0.000192    |
# |    std                  | 0.57         |
# |    value_loss           | 0.563        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 4.17       |
# | time/                   |            |
# |    fps                  | 25285      |
# |    iterations           | 97         |
# |    time_elapsed         | 383        |
# |    total_timesteps      | 9700000    |
# | train/                  |            |
# |    approx_kl            | 0.00134316 |
# |    clip_fraction        | 0.00431    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.71      |
# |    explained_variance   | 0.58       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.303      |
# |    n_updates            | 288        |
# |    policy_gradient_loss | 4.45e-05   |
# |    std                  | 0.567      |
# |    value_loss           | 0.59       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 4.51        |
# | time/                   |             |
# |    fps                  | 25293       |
# |    iterations           | 98          |
# |    time_elapsed         | 387         |
# |    total_timesteps      | 9800000     |
# | train/                  |             |
# |    approx_kl            | 0.002206628 |
# |    clip_fraction        | 0.01        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.589       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.293       |
# |    n_updates            | 291         |
# |    policy_gradient_loss | -9.21e-05   |
# |    std                  | 0.564       |
# |    value_loss           | 0.585       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.08         |
# | time/                   |              |
# |    fps                  | 25304        |
# |    iterations           | 99           |
# |    time_elapsed         | 391          |
# |    total_timesteps      | 9900000      |
# | train/                  |              |
# |    approx_kl            | 0.0029039658 |
# |    clip_fraction        | 0.00867      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.69        |
# |    explained_variance   | 0.575        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.306        |
# |    n_updates            | 294          |
# |    policy_gradient_loss | -1.52e-06    |
# |    std                  | 0.562        |
# |    value_loss           | 0.606        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.38         |
# | time/                   |              |
# |    fps                  | 25310        |
# |    iterations           | 100          |
# |    time_elapsed         | 395          |
# |    total_timesteps      | 10000000     |
# | train/                  |              |
# |    approx_kl            | 0.0021301745 |
# |    clip_fraction        | 0.0105       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.68        |
# |    explained_variance   | 0.603        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.284        |
# |    n_updates            | 297          |
# |    policy_gradient_loss | -0.000104    |
# |    std                  | 0.558        |
# |    value_loss           | 0.563        |
# ------------------------------------------

# %% [markdown]
# ## Comparing the learnt policy to the optimal policy

# %%
from agents.SbAgent import SbAgent

# %%
ppo_agent = SbAgent(model)

# %%
inventories = np.arange(-3,4,1)
bid_actions = []
ask_actions = []
for inventory in inventories:
    bid_action, ask_action = ppo_agent.get_action(np.array([[inventory,0.5]])).reshape(-1)
    bid_actions.append(bid_action)
    ask_actions.append(ask_action)

# %%
#ppo_agent.get_action(np.array([[inventory,0.5]]))

# %%
cj_agent = CarteaJaimungalMmAgent(env=get_cj_env())

# %%
# Get the Cartea Jaimungal action
cj_bid_actions = []
cj_ask_actions = []
for inventory in inventories:
    bid_action, ask_action = cj_agent.get_action(np.array([[0,inventory,0.5]])).reshape(-1)
    cj_bid_actions.append(bid_action)
    cj_ask_actions.append(ask_action)

# %%
plt.plot(inventories, bid_actions, label = "bid", color = "k")
plt.plot(inventories, ask_actions, label = "ask", color = "r")
plt.plot(inventories, cj_bid_actions, label = "bid cj", color = "k", linestyle = "--")
plt.plot(inventories, cj_ask_actions, label = "ask cj", color = "r", linestyle = "--")
plt.legend()
